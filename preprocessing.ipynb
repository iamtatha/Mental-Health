# %% [markdown]
# <a href="https://colab.research.google.com/github/tathaiitb/Mental-Health-Prediction/blob/main/MH1_Visualize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing as pp
df = pd.read_csv("https://raw.githubusercontent.com/iamtatha/Data_Science/master/survey.csv")
headers = list(df.keys())

# %%
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
pip install sdv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 102 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 35.6 MB/s
# ...
#      |████████████████████████████████| 131 kB 52.7 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 61 kB 346 kB/s
# ...
#      |████████████████████████████████| 47 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 43.5 MB/s
# ...
#      |████████████████████████████████| 965 kB 44.5 MB/s
# ...
#      |████████████████████████████████| 280 kB 24.2 MB/s
# ...
#      |████████████████████████████████| 636 kB 59.3 MB/s
# ...
#      |████████████████████████████████| 15.3 MB 44.2 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
# ...

# %%
from sdv.tabular import GaussianCopula
model = GaussianCopula()
model.fit(df)

# %%
plt.figure(figsize=(20,10))
df['Gender'].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()

# %%
plt.figure(figsize=(20,10))
df['Gender'].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()

# %%
# df['Age'].plot(kind='density', subplots=True, layout=(1,1), sharex=False)
df['Age'].unique()
# Out:
# array([         37,          44,          32,          31,          33,
#                 35,          39,          42,          23,          29,
#                 36,          27,          46,          41,          34,
#                 30,          40,          38,          50,          24,
#                 18,          28,          26,          22,          19,
#                 25,          45,          21,         -29,          43,
#                 56,          60,          54,         329,          55,
#        99999999999,          48,          20,          57,          58,
#                 47,          62,          51,          65,          49,
#              -1726,           5,          53,          61,           8,
#                 11,          -1,          72])

# %%
sns.distplot(df['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8,6))
df['self_employed'].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
print(df['self_employed'].unique())
sns.distplot(df['self_employed'])
# Out:
# [2 1 0]
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8,6))
df['family_history'].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
# sns.distplot(df['family_history'])

# %%
plt.figure(figsize=(8,6))
df['treatment'].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
sns.distplot(df['treatment'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8,6))
df['work_interfere'].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
sns.distplot(labelEncoding(df, 'work_interfere')['work_interfere'])
# print(labelEncoding(df, 'work_interfere')['work_interfere'])
# sns.distplot(labelEncoding(df, 'col')['col'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8,6))
df['no_employees'].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
col = 'no_employees'
sns.distplot(labelEncoding(df, col)[col])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
col = 'remote_work'
plt.figure(figsize=(8,6))
df[col].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
print(df[col].unique())
sns.distplot(labelEncoding(df, col)[col])
# Out:
# [0 1]
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
col = 'tech_company'
plt.figure(figsize=(8,6))
df[col].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
print(df[col].unique())
sns.distplot(labelEncoding(df, col)[col])
# Out:
# [1 0]
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
col = 'benefits'
plt.figure(figsize=(8,6))
df[col].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
print(df[col].unique())
sns.distplot(labelEncoding(df, col)[col])
# Out:
# ['Yes' "Don't know" 'No']
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
col = 'care_options'
plt.figure(figsize=(8,6))
df[col].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
print(df[col].unique())
sns.distplot(labelEncoding(df, col)[col])
# Out:
# ['Not sure' 'No' 'Yes']
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
col = 'wellness_program'
plt.figure(figsize=(8,6))
df[col].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
print(df[col].unique())
sns.distplot(labelEncoding(df, col)[col])
# Out:
# ['No' "Don't know" 'Yes']
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
col = 'seek_help'
plt.figure(figsize=(8,6))
df[col].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
print(df[col].unique())
sns.distplot(labelEncoding(df, col)[col])
# Out:
# ['Yes' "Don't know" 'No']
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
col = 'anonymity'
plt.figure(figsize=(8,6))
df[col].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
print(df[col].unique())
sns.distplot(labelEncoding(df, col)[col])
# Out:
# ['Yes' "Don't know" 'No']
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
col = 'leave'
plt.figure(figsize=(8,6))
df[col].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
l = df[col].unique()
f = sns.distplot(labelEncoding(df, col)[col])
# f.set_xticklabels(list(l))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
col = 'mental_health_consequence'
plt.figure(figsize=(8,6))
df[col].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
print(df[col].unique())
l = df[col].unique()
f = sns.distplot(labelEncoding(df, col)[col])
# Out:
# [1 0 2]
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
col = 'phys_health_consequence'
plt.figure(figsize=(8,6))
df[col].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
print(df[col].unique())
f = sns.distplot(labelEncoding(df, col)[col])
# Out:
# ['No' 'Yes' 'Maybe']
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
col = 'coworkers'
plt.figure(figsize=(8,6))
df[col].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
print(df[col].unique())
f = sns.distplot(labelEncoding(df, col)[col])
# Out:
# ['Some of them' 'No' 'Yes']
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
col = 'supervisor'
plt.figure(figsize=(8,6))
df[col].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
print(df[col].unique())
f = sns.distplot(labelEncoding(df, col)[col])
# Out:
# ['Yes' 'No' 'Some of them']
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
col = 'mental_health_interview'
plt.figure(figsize=(8,6))
df[col].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
print(df[col].unique())
f = sns.distplot(labelEncoding(df, col)[col])
# Out:
# ['No' 'Yes' 'Maybe']
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
col = 'phys_health_interview'
plt.figure(figsize=(8,6))
df[col].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
print(df[col].unique())
f = sns.distplot(labelEncoding(df, col)[col])
# Out:
# ['Maybe' 'No' 'Yes']
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
col = 'mental_vs_physical'
plt.figure(figsize=(8,6))
df[col].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
print(df[col].unique())
f = sns.distplot(labelEncoding(df, col)[col])
# Out:
# ['Yes' "Don't know" 'No']
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
col = 'obs_consequence'
plt.figure(figsize=(8,6))
df[col].value_counts().plot(kind='bar')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.show()
print(df[col].unique())
f = sns.distplot(labelEncoding(df, col)[col])
# Out:
# ['No' 'Yes']

# %%
col = 'Country'
f = sns.distplot(labelEncoding(df, col)[col])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
headers
# Out:
# ['Timestamp',
#  'Age',
#  'Gender',
#  'Country',
#  'state',
#  'self_employed',
#  'family_history',
#  'treatment',
#  'work_interfere',
#  'no_employees',
#  'remote_work',
#  'tech_company',
#  'benefits',
#  'care_options',
#  'wellness_program',
#  'seek_help',
#  'anonymity',
#  'leave',
#  'mental_health_consequence',
#  'phys_health_consequence',
#  'coworkers',
#  'supervisor',
#  'mental_health_interview',
#  'phys_health_interview',
#  'mental_vs_physical',
#  'obs_consequence',
#  'comments']

# %%
df = pd.read_csv("https://raw.githubusercontent.com/iamtatha/Data_Science/master/survey.csv")
headers = list(df.keys())

# %%
male_str = ["male", "m", "male-ish", "maile", "mal", "male (cis)", "make", "male ", "man","msle", "mail", "malr","cis man", "Cis Male", "cis male"]
trans_str = ["trans-female", "something kinda male?", "queer/she/they", "non-binary","nah", "all", "enby", "fluid", "genderqueer", "androgyne", "agender", "male leaning androgynous", "guy (-ish) ^_^", "trans woman", "neuter", "female (trans)", "queer", "ostensibly male, unsure what that really means"]           
female_str = ["cis female", "f", "female", "woman",  "femake", "female ","cis-female/femme", "female (cis)", "femail"]


for i in range(len(df['Gender'])):
  text = df['Gender'][i].lower()
  if text in male_str:
    change = 'M'
  elif text in female_str:
    change = 'F'
  else:
    change  = 'T'
  df['Gender'][i] = change
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
one_hot_cols = ['work_interfere', 'benefits', 'care_options', 'wellness_program', 'seek_help', 'anonymity', 'leave', 'mental_health_consequence',
 'phys_health_consequence', 'coworkers', 'supervisor', 'mental_health_interview', 'phys_health_interview','mental_vs_physical',]

label_cols = ['Age', 'Gender', 'Country', 'state', 'self_employed', 'family_history', 'no_employees', 'remote_work', 'tech_company']

# %%
def labelEncoding(df, col):
  le = pp.LabelEncoder()
  df[col] = le.fit_transform(df[col])
  return df

# %%
def oneHotEncoding(df, col):
  df = pd.get_dummies(df, col)
  return df

# %%
for i in headers:
  if i not in one_hot_cols and i!='Age':
    df = labelEncoding(df, i)
  else:
    df = labelEncoding(df, i)
# df = oneHotEncoding(df, one_hot_cols)

# %%
for i in range(len(df['Age'])):
  if(df['Age'][i]>124 or df['Age'][i]<0):
    df['Age'][i]=df['Age'].median()

# %%
df_x = df.drop(['Timestamp', 'treatment', 'obs_consequence', 'comments'], axis = 1)
df_y = df['treatment']

train_y = np.array(df_y).reshape(1259,1)
train_x = np.array(df_x)

df_y.to_csv('target.csv', index=False)
df_x.to_csv('train.csv', index=False)

# %%
train_x.shape
# Out:
# (1259, 23)

# %%
train_y.shape
# Out:
# (1259, 1)

# %%
sns.distplot(df['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Gender'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
for i in headers:
  df = labelEncoding(df, i)
df.head()
# Out:
#    Timestamp  Age  Gender  Country  state  self_employed  family_history  \
# 0          0   25       0       45     10              2               0
# 1          1   32       1       45     11              2               0
# 2          2   20       1        7     45              2               0
# 3          3   19       1       44     45              2               1
# 4          4   19       1       45     37              2               0
#
#    treatment  work_interfere  no_employees  ...  leave  \
# 0          1               1             4  ...      2
# 1          0               2             5  ...      0
# 2          0               2             4  ...      1
# 3          1               1             2  ...      1
# 4          0               0             1  ...      0
#
#    mental_health_consequence  phys_health_consequence  coworkers  supervisor  \
# 0                          1                        1          1           2
# ...

# %%
df_x = df.drop(['Timestamp', 'treatment', 'obs_consequence', 'comments'], axis = 1)
df_y = df['treatment']

train_y = np.array(df_y).reshape(1259,1)
train_x = np.array(df_x)

df_y.to_csv('target.csv', index=False)
df_x.to_csv('train.csv', index=False)

# %%
glue = sns.load_dataset("glue").pivot("Model", "Task", "Score")
sns.heatmap(glue)
